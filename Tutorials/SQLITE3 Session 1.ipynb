# %% [markdown]
# # Why do we need SQL?

# %% [markdown]
# In real world data is not stored in a single file (csv,txt..,). It is always stored in a database. SQL is used to retrieve data from databases.

# %% [markdown]
# # What is SQL

# %% [markdown]
# <ul>
#     <li> SQL stands for Structured Query Language </li>
#     <li> Used for storing, manipulating and retrieving data in RDBMS (what is RDBMS?)</li>
#     <li> Even though SQL is a standard language the syntax varies a bit for each database (MySQL, Oracle,SQlite..,)</li>
# </ul>

# %% [markdown]
# ### Scope of this SQL course

# %% [markdown]
# In this course we will only be looking at the data retrieving part of SQL. Data storing and manipulation is usually taken care by the data engineers.

# %% [markdown]
# ### Creation of SQLITE database

# %% [markdown]
# Execute all the cells of "Database & Table Creation" notebook which you can find it in the SQL section of the course. This will create a SQLITE databse on your local machine.

# %% [markdown]
# ### Importing Libraries

# %%
import sqlite3 as sl
import pandas as pd

# %% [markdown]
# ### Creating connection to DB

# %%
con = sl.connect('sql_invoicing_1.db')

# %%
# List of tables in the database

cursorObj = con.cursor()

cursorObj.execute('SELECT name from sqlite_master where type= "table"')

print(cursorObj.fetchall())
# Out:
# [('payment_methods',), ('sqlite_sequence',), ('clients',), ('invoices',), ('payments',), ('products',), ('shippers',), ('customers',), ('order_statuses',), ('orders',), ('order_items',), ('order_item_notes',), ('offices',), ('employees',)]

# %% [markdown]
#  #### Retrieve all rows and columns of a table

# %%
Query = """
        select *
        from invoices;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#    invoice_id       number  client_id  invoice_total  payment_total  \
# 0           1  91-953-3396          2         101.79           0.00
# 1           2  03-898-6735          5         175.32           8.18
# 2           3  20-228-0335          5         147.99           0.00
# 3           4  56-934-0748          3         152.21           0.00
# 4           5  87-052-3121          5         169.36           0.00
#
#   invoice_date    due_date payment_date
# 0   2019-03-09  2019-03-29         None
# 1   2019-06-11  2019-07-01   2019-06-30
# 2   2019-07-31  2019-08-20         None
# 3   2019-03-08  2019-03-28         None
# 4   2019-07-18  2019-08-07         None

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### Class Task: Retrieve all columns and rows from any table

# %% [markdown]
# #### Selecting specific columns from a table

# %%
Query = """
       select number,invoice_total,invoice_date,due_date,payment_date
       from invoices ;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#         number  invoice_total invoice_date    due_date payment_date
# 0  91-953-3396         101.79   2019-03-09  2019-03-29         None
# 1  03-898-6735         175.32   2019-06-11  2019-07-01   2019-06-30
# 2  20-228-0335         147.99   2019-07-31  2019-08-20         None
# 3  56-934-0748         152.21   2019-03-08  2019-03-28         None
# 4  87-052-3121         169.36   2019-07-18  2019-08-07         None

# %% [markdown]
# ##### Class Task: Query a table by using specific column names

# %% [markdown]
# #### LIMIT can be used to output limited number of rows to understand the data

# %%
Query = """
       select number,invoice_total,invoice_date,due_date,payment_date
       from invoices 
       limit 5;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#         number  invoice_total invoice_date    due_date payment_date
# 0  91-953-3396         101.79   2019-03-09  2019-03-29         None
# 1  03-898-6735         175.32   2019-06-11  2019-07-01   2019-06-30
# 2  20-228-0335         147.99   2019-07-31  2019-08-20         None
# 3  56-934-0748         152.21   2019-03-08  2019-03-28         None
# 4  87-052-3121         169.36   2019-07-18  2019-08-07         None

# %% [markdown]
# #### ORDER BY orders the result by based on a column

# %%
Query = """
       select number,invoice_total,invoice_date,due_date,payment_date
       from invoices 
       order by invoice_total desc;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#         number  invoice_total invoice_date    due_date payment_date
# 0  78-145-1093         189.12   2019-05-20  2019-06-09         None
# 1  52-269-9803         180.17   2019-05-23  2019-06-12   2019-06-08
# 2  03-898-6735         175.32   2019-06-11  2019-07-01   2019-06-30
# 3  77-593-0081         172.17   2019-07-09  2019-07-29         None
# 4  87-052-3121         169.36   2019-07-18  2019-08-07         None

# %% [markdown]
# #### By default ORDER BY orders the data in ascending order

# %%
Query = """
       select number,invoice_total,invoice_date,due_date,payment_date
       from invoices 
       order by invoice_total;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#         number  invoice_total invoice_date    due_date payment_date
# 0  91-953-3396         101.79   2019-03-09  2019-03-29         None
# 1  20-848-0181         126.15   2019-01-07  2019-01-27   2019-01-27
# 2  33-615-4694         126.38   2019-07-30  2019-08-19   2019-08-15
# 3  68-093-9863         133.87   2019-09-04  2019-09-24         None
# 4  83-559-4105         134.47   2019-11-23  2019-12-13         None

# %% [markdown]
# #### WHERE clause is used to extract data based on some condition

# %%
# Query the table to extract data of one particular client
Query = """
       select *
       from invoices 
       where client_id = 5;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#    invoice_id       number  client_id  invoice_total  payment_total  \
# 0           2  03-898-6735          5         175.32           8.18
# 1           3  20-228-0335          5         147.99           0.00
# 2           5  87-052-3121          5         169.36           0.00
# 3           9  77-593-0081          5         172.17           0.00
# 4          13  41-666-1035          5         135.01          87.44
# 5          18  52-269-9803          5         180.17          42.77
#
#   invoice_date    due_date payment_date
# 0   2019-06-11  2019-07-01   2019-06-30
# 1   2019-07-31  2019-08-20         None
# 2   2019-07-18  2019-08-07         None
# 3   2019-07-09  2019-07-29         None
# 4   2019-06-25  2019-07-15   2019-07-13
# 5   2019-05-23  2019-06-12   2019-06-08

# %% [markdown]
# ##### Class Task: Retrieve all invoice observations where the payment is not done

# %% [markdown]
# #### <,>,<=,>=,<> are other comparison operators which can be used with WHERE clause

# %%
Query = """
       select *
       from invoices 
       where invoice_total  >= 150;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#    invoice_id       number  client_id  invoice_total  payment_total  \
# 0           2  03-898-6735          5         175.32           8.18
# 1           4  56-934-0748          3         152.21           0.00
# 2           5  87-052-3121          5         169.36           0.00
# 3           6  75-587-6626          1         157.78          74.55
# 4           8  78-145-1093          1         189.12           0.00
#
#   invoice_date    due_date payment_date
# 0   2019-06-11  2019-07-01   2019-06-30
# 1   2019-03-08  2019-03-28         None
# 2   2019-07-18  2019-08-07         None
# 3   2019-01-29  2019-02-18   2019-02-20
# 4   2019-05-20  2019-06-09         None

# %%
Query = """
       select *
       from invoices 
       where client_id  <> 5;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#    invoice_id       number  client_id  invoice_total  payment_total  \
# 0           1  91-953-3396          2         101.79           0.00
# 1           4  56-934-0748          3         152.21           0.00
# 2           6  75-587-6626          1         157.78          74.55
# 3           7  68-093-9863          3         133.87           0.00
# 4           8  78-145-1093          1         189.12           0.00
#
#   invoice_date    due_date payment_date
# 0   2019-03-09  2019-03-29         None
# 1   2019-03-08  2019-03-28         None
# 2   2019-01-29  2019-02-18   2019-02-20
# 3   2019-09-04  2019-09-24         None
# 4   2019-05-20  2019-06-09         None

# %% [markdown]
# #### Logical operators (AND,OR,NOT,BETWEEN,IN)

# %%
# Using AND operator
Query = """
       select *
       from invoices 
       where invoice_total  >= 150 and payment_total = 0;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#    invoice_id       number  client_id  invoice_total  payment_total  \
# 0           4  56-934-0748          3         152.21              0
# 1           5  87-052-3121          5         169.36              0
# 2           8  78-145-1093          1         189.12              0
# 3           9  77-593-0081          5         172.17              0
# 4          10  48-266-1517          1         159.50              0
# 5          16  10-451-8824          1         162.02              0
#
#   invoice_date    due_date payment_date
# 0   2019-03-08  2019-03-28         None
# 1   2019-07-18  2019-08-07         None
# 2   2019-05-20  2019-06-09         None
# 3   2019-07-09  2019-07-29         None
# 4   2019-06-30  2019-07-20         None
# 5   2019-03-30  2019-04-19         None

# %%
# Using BETWEEN operator
 # Let's have a look at employees table
Query = """
       select *
       from employees;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#     employee_id  first_name   last_name                    job_title  salary  \
# 0         37270    Yovonnda  Magrannell          Executive Secretary   63996
# 1         33391      D'arcy    Nortunen            Account Executive   62871
# 2         37851       Sayer   Matterson             Statistician III   98926
# 3         40448       Mindy     Crissil              Staff Scientist   94860
# 4         56274     Keriann     Alloisi                 VP Marketing  110150
# 5         63196     Alaster    Scutchin          Assistant Professor   32179
# 6         67009       North    de Clerc        VP Product Management  114257
# 7         67370    Elladine      Rising                Social Worker   96767
# 8         68249       Nisse      Voysey            Financial Advisor   52832
# 9         72540     Guthrey   Iacopetti           Office Assistant I  117690
# 10        72913        Kass    Hefferan  Computer Systems Analyst IV   96401
# 11        75900       Virge     Goodrum  Information Systems Manager   54578
# 12        76196     Mirilla    Janowski              Cost Accountant  119241
# 13        80529       Lynde     Aronson             Junior Executive   77182
# 14        80679     Mildrid      Sokale                 Geologist II   67987
# 15        84791       Hazel     Tarbert              General Manager   93760
# 16        95213        Cole   Kesterton                   Pharmacist   86119
# 17        96513     Theresa      Binney                 Food Chemist   47354
# 18        98374  Estrellita     Daleman          Staff Accountant IV   70187
# 19       115357         Ivy      Fearey          Structural Engineer   92710
#
#     reports_to  office_id
# 0          NaN         10
# 1      37270.0          1
# 2      37270.0          1
# 3      37270.0          1
# 4      37270.0          1
# 5      37270.0          2
# 6      37270.0          2
# 7      37270.0          2
# 8      37270.0          2
# 9      37270.0          3
# 10     37270.0          3
# 11     37270.0          3
# 12     37270.0          3
# 13     37270.0          4
# 14     37270.0          4
# 15     37270.0          4
# 16     37270.0          4
# 17     37270.0          5
# 18     37270.0          5
# 19     37270.0          5

# %%
Query = """
       select *
       from employees
       where salary between 70000 and 100000;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#    employee_id  first_name  last_name                    job_title  salary  \
# 0        37851       Sayer  Matterson             Statistician III   98926
# 1        40448       Mindy    Crissil              Staff Scientist   94860
# 2        67370    Elladine     Rising                Social Worker   96767
# 3        72913        Kass   Hefferan  Computer Systems Analyst IV   96401
# 4        80529       Lynde    Aronson             Junior Executive   77182
# 5        84791       Hazel    Tarbert              General Manager   93760
# 6        95213        Cole  Kesterton                   Pharmacist   86119
# 7        98374  Estrellita    Daleman          Staff Accountant IV   70187
# 8       115357         Ivy     Fearey          Structural Engineer   92710
#
#    reports_to  office_id
# 0       37270          1
# 1       37270          1
# 2       37270          2
# 3       37270          3
# 4       37270          4
# 5       37270          4
# 6       37270          4
# 7       37270          5
# 8       37270          5

# %%
# Using NOT operator
Query = """
       select *
       from employees
       where salary not between 70000 and 100000
       order by salary;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#     employee_id first_name   last_name                    job_title  salary  \
# 0         63196    Alaster    Scutchin          Assistant Professor   32179
# 1         96513    Theresa      Binney                 Food Chemist   47354
# 2         68249      Nisse      Voysey            Financial Advisor   52832
# 3         75900      Virge     Goodrum  Information Systems Manager   54578
# 4         33391     D'arcy    Nortunen            Account Executive   62871
# 5         37270   Yovonnda  Magrannell          Executive Secretary   63996
# 6         80679    Mildrid      Sokale                 Geologist II   67987
# 7         56274    Keriann     Alloisi                 VP Marketing  110150
# 8         67009      North    de Clerc        VP Product Management  114257
# 9         72540    Guthrey   Iacopetti           Office Assistant I  117690
# 10        76196    Mirilla    Janowski              Cost Accountant  119241
#
#     reports_to  office_id
# 0      37270.0          2
# 1      37270.0          5
# 2      37270.0          2
# 3      37270.0          3
# 4      37270.0          1
# 5          NaN         10
# 6      37270.0          4
# 7      37270.0          1
# 8      37270.0          2
# 9      37270.0          3
# 10     37270.0          3

# %%
# Using IN Operator
Query = """
       select *
       from employees
       where office_id in (2,3);
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#    employee_id first_name  last_name                    job_title  salary  \
# 0        63196    Alaster   Scutchin          Assistant Professor   32179
# 1        67009      North   de Clerc        VP Product Management  114257
# 2        67370   Elladine     Rising                Social Worker   96767
# 3        68249      Nisse     Voysey            Financial Advisor   52832
# 4        72540    Guthrey  Iacopetti           Office Assistant I  117690
# 5        72913       Kass   Hefferan  Computer Systems Analyst IV   96401
# 6        75900      Virge    Goodrum  Information Systems Manager   54578
# 7        76196    Mirilla   Janowski              Cost Accountant  119241
#
#    reports_to  office_id
# 0       37270          2
# 1       37270          2
# 2       37270          2
# 3       37270          2
# 4       37270          3
# 5       37270          3
# 6       37270          3
# 7       37270          3

# %% [markdown]
# #### LIKE & WILDCARDS

# %%
# '%' denotes any number of characters
Query = """
       select *
       from employees
       where first_name like 'm%';
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#    employee_id first_name last_name        job_title  salary  reports_to  \
# 0        40448      Mindy   Crissil  Staff Scientist   94860       37270
# 1        76196    Mirilla  Janowski  Cost Accountant  119241       37270
# 2        80679    Mildrid    Sokale     Geologist II   67987       37270
#
#    office_id
# 0          1
# 1          3
# 2          4

# %% [markdown]
# ##### Class Task: Output all the observations where the job title ends with 'manager' or 'management'

# %%
# '_' denotes one character
Query = """
       select *
       from employees
       where first_name like '_i%';
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#    employee_id first_name last_name                    job_title  salary  \
# 0        40448      Mindy   Crissil              Staff Scientist   94860
# 1        68249      Nisse    Voysey            Financial Advisor   52832
# 2        75900      Virge   Goodrum  Information Systems Manager   54578
# 3        76196    Mirilla  Janowski              Cost Accountant  119241
# 4        80679    Mildrid    Sokale                 Geologist II   67987
#
#    reports_to  office_id
# 0       37270          1
# 1       37270          2
# 2       37270          3
# 3       37270          3
# 4       37270          4

# %% [markdown]
# #### Working with DATES

# %%
Query = """
       select *,strftime('%m',invoice_date) as month_number
    
       from invoices;
        """
df = pd.read_sql_query(Query,con)
df.head()
# Out:
#    invoice_id       number  client_id  invoice_total  payment_total  \
# 0           1  91-953-3396          2         101.79           0.00
# 1           2  03-898-6735          5         175.32           8.18
# 2           3  20-228-0335          5         147.99           0.00
# 3           4  56-934-0748          3         152.21           0.00
# 4           5  87-052-3121          5         169.36           0.00
#
#   invoice_date    due_date payment_date month_number
# 0   2019-03-09  2019-03-29         None           03
# 1   2019-06-11  2019-07-01   2019-06-30           06
# 2   2019-07-31  2019-08-20         None           07
# 3   2019-03-08  2019-03-28         None           03
# 4   2019-07-18  2019-08-07         None           07

# %% [markdown]
# ##### Class Task: Output all the cases where the payment month is July

# %% [markdown]
# Here you can find more about strftime function<br> https://www.sqlite.org/lang_datefunc.html

# %%
# Difference between date
Query = """
       select *,strftime('%J',payment_date)-strftime('%J',invoice_date) as Date_Diff
    
       from invoices;
        """
df = pd.read_sql_query(Query,con)
df
# Out:
#     invoice_id       number  client_id  invoice_total  payment_total  \
# 0            1  91-953-3396          2         101.79           0.00
# 1            2  03-898-6735          5         175.32           8.18
# 2            3  20-228-0335          5         147.99           0.00
# 3            4  56-934-0748          3         152.21           0.00
# 4            5  87-052-3121          5         169.36           0.00
# 5            6  75-587-6626          1         157.78          74.55
# 6            7  68-093-9863          3         133.87           0.00
# 7            8  78-145-1093          1         189.12           0.00
# 8            9  77-593-0081          5         172.17           0.00
# 9           10  48-266-1517          1         159.50           0.00
# 10          11  20-848-0181          3         126.15           0.03
# 11          13  41-666-1035          5         135.01          87.44
# 12          15  55-105-9605          3         167.29          80.31
# 13          16  10-451-8824          1         162.02           0.00
# 14          17  33-615-4694          3         126.38          68.10
# 15          18  52-269-9803          5         180.17          42.77
# 16          19  83-559-4105          1         134.47           0.00
#
#    invoice_date    due_date payment_date  Date_Diff
# 0    2019-03-09  2019-03-29         None        NaN
# 1    2019-06-11  2019-07-01   2019-06-30       19.0
# 2    2019-07-31  2019-08-20         None        NaN
# 3    2019-03-08  2019-03-28         None        NaN
# 4    2019-07-18  2019-08-07         None        NaN
# 5    2019-01-29  2019-02-18   2019-02-20       22.0
# 6    2019-09-04  2019-09-24         None        NaN
# 7    2019-05-20  2019-06-09         None        NaN
# 8    2019-07-09  2019-07-29         None        NaN
# 9    2019-06-30  2019-07-20         None        NaN
# 10   2019-01-07  2019-01-27   2019-01-27       20.0
# 11   2019-06-25  2019-07-15   2019-07-13       18.0
# 12   2019-11-25  2019-12-15   2019-12-10       15.0
# 13   2019-03-30  2019-04-19         None        NaN
# 14   2019-07-30  2019-08-19   2019-08-15       16.0
# 15   2019-05-23  2019-06-12   2019-06-08       16.0
# 16   2019-11-23  2019-12-13         None        NaN

# %% [markdown]
# #### Handling NULL values

# %% [markdown]
#  <i>Extract sample data

# %%
Query = """
           select *
           from invoices
        """
df = pd.read_sql_query(Query,con)
df

# %% [markdown]
# <i>Extracting rows with payment_date null

# %%
Query = """
          select client_id,invoice_id,invoice_total,invoice_date,payment_date
from invoices
where payment_date is null;
        """
df = pd.read_sql_query(Query,con)
df

# %% [markdown]
# ##### Class Task : Extracting rows where the payment has been made

# %% [markdown]
# <i> Replacing NULL with "0000-00-00" using "ifnull"

# %%
Query = """
          select ifnull(payment_date,'0000-00-00') as payment_v1
          from invoices;
        """
df = pd.read_sql_query(Query,con)
df

# %% [markdown]
# ##### Class Task: Extract "invoices" table with a new column "Date_Diff" which denotes number of days since invoice and payment. For cases where payment is not done consider current date as payment date
